# %% [markdown]
# ### 실습: 왓챠 영화 목록 데이터 프레임으로 가져오기

# %%
# 필요한 라이브러리 임포트
import pandas as pd
import requests

# %% [markdown]
#  - Watcha에서 자체 제작한 영화 콜렉션인 Watcha 최고 인기작 컬렉션을 크롤링해 csv 파일로 저장해 봅시다.
#  - 아래 링크를 클릭해 보세요.
#     - https://pedia.watcha.com/ko-KR/staffmades/278

# %% [markdown]
# #### 문제1: 링크된 페이지에서 크롬 개발자 도구를 이용해 로딩할 때 데이터를 어떻게 가져오는지 확인해 보고, Request를 모방해서 응답받은 JSON을 딕셔너리로 이루어진 리스트를 `top_movies` 리스트에 저장하세요.

# %%
import requests

cookies = {
    '_c_di_v2': 'web--J3Vy5evqgCwuJkbVXqi1a7ofZYpkT',
    'cto_bundle': '',
    '_gid': 'GA1.2.1980733004.1705543403',
    '_ga_1PF16G1LBX': 'GS1.1.1705543393.1.0.1705543425.0.0.0',
    '_c_pdi': 'web-bAxBceru79wPlT3k04mmxgsPZjzjjv',
    '_gat_gtag_UA_27006241_7': '1',
    '_gat_UA-27006241-7': '1',
    '_ga': 'GA1.1.1873569764.1705543394',
    '_ga_S4YE5E5P6R': 'GS1.1.1705543428.1.1.1705543867.0.0.0',
    '_ga_1PYHGTCRYW': 'GS1.1.1705543428.1.1.1705543867.0.0.0',
}

headers = {
    'authority': 'pedia.watcha.com',
    'accept': 'application/vnd.frograms+json;version=20',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # 'cookie': '_c_di_v2=web--J3Vy5evqgCwuJkbVXqi1a7ofZYpkT; cto_bundle=; _gid=GA1.2.1980733004.1705543403; _ga_1PF16G1LBX=GS1.1.1705543393.1.0.1705543425.0.0.0; _c_pdi=web-bAxBceru79wPlT3k04mmxgsPZjzjjv; _gat_gtag_UA_27006241_7=1; _gat_UA-27006241-7=1; _ga=GA1.1.1873569764.1705543394; _ga_S4YE5E5P6R=GS1.1.1705543428.1.1.1705543867.0.0.0; _ga_1PYHGTCRYW=GS1.1.1705543428.1.1.1705543867.0.0.0',
    'if-none-match': 'W/"cb9a6970c8125eba9d5fd8ac0e6e340c"',
    'referer': 'https://pedia.watcha.com/ko-KR/staffmades/278',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
    'x-forwarded-for': 'null',
    'x-frograms-app-code': 'Galaxy',
    'x-frograms-client': 'Galaxy-Web-App',
    'x-frograms-client-version': '2.1.0',
    'x-frograms-device-identifier': 'web-bAxBceru79wPlT3k04mmxgsPZjzjjv',
    'x-frograms-galaxy-language': 'ko',
    'x-frograms-galaxy-region': 'KR',
    'x-frograms-version': '2.1.0',
    'x-watcha-client-language': 'ko',
    'x-watcha-client-region': 'KR',
    'x-watcha-remote-addr': '1.231.19.126',
}

params = {
    'page': '2',
    'size': '9',
}

# %%
import time
import random
top_movies = []
for i in range(35):
    response = requests.get('https://pedia.watcha.com/api/staffmades/278/contents?page=1&size9',  cookies=cookies, headers=headers)
    response= response.json()['result']["result"]
    top_movies.extend(response)

    time.sleep(random.randrange(1,5))

# %%
top_movies
# Out:
# [{'code': 'md76rkk',
#   'content_type': 'movies',
#   'title': '스파이더맨: 뉴 유니버스',
#   'year': 2018,
#   'poster': {'hd': 'https://an2-img.amz.wtchn.net/image/v2/CG5nQZxGf_bG3xVnrCqC2Q.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk9EazJlREV5T0RCeE9EQWlYU3dpY0NJNklpOTJNUzlvYW5OM2FXNTJiSGgwYzNOMU9XRjNZbTV4WkNKOS5DVS05Z2xtWDVfMG9LNWZqeUl2ZDhlVVhUTFFycHRJOWlDV0JoZjJUVkdN',
#    'xlarge': 'https://an2-img.amz.wtchn.net/image/v2/svtqFaUlHtXXRptTh4Golg.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk5Ea3dlRGN3TUhFNE1DSmRMQ0p3SWpvaUwzWXhMMmhxYzNkcGJuWnNlSFJ6YzNVNVlYZGlibkZrSW4wLlppTmVPY1BLVzRTY1NrNjVPWVJwemkyUG0tMUNIRnVMOGxLUTJucUprclk',
#    'large': 'https://an2-img.amz.wtchn.net/image/v2/y2nF6sCn00RvWE1O_4XRuA.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk1qZ3dlRFF3TUhFNE1DSmRMQ0p3SWpvaUwzWXhMMmhxYzNkcGJuWnNlSFJ6YzNVNVlYZGlibkZrSW4wLjE5WEdaMlduZUhTTEJfMGlQazBSMEdZbHB4TzVfaUJ2NWJ0U1U0N1JiUDQ',
# ...

# %% [markdown]
# #### 문제 2: 수집한 `top_movies` 리스트 안에 있는 딕셔너리에서 `code`, `title`, `year`, `ratings_avg`, `nations`, `genres`만 남기고 나머지는 필요 없으니 없애버리세요.

# %%
print(top_movies[0])
# Out:
# {'code': 'md76rkk', 'content_type': 'movies', 'title': '스파이더맨: 뉴 유니버스', 'year': 2018, 'poster': {'hd': 'https://an2-img.amz.wtchn.net/image/v2/CG5nQZxGf_bG3xVnrCqC2Q.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk9EazJlREV5T0RCeE9EQWlYU3dpY0NJNklpOTJNUzlvYW5OM2FXNTJiSGgwYzNOMU9XRjNZbTV4WkNKOS5DVS05Z2xtWDVfMG9LNWZqeUl2ZDhlVVhUTFFycHRJOWlDV0JoZjJUVkdN', 'xlarge': 'https://an2-img.amz.wtchn.net/image/v2/svtqFaUlHtXXRptTh4Golg.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk5Ea3dlRGN3TUhFNE1DSmRMQ0p3SWpvaUwzWXhMMmhxYzNkcGJuWnNlSFJ6YzNVNVlYZGlibkZrSW4wLlppTmVPY1BLVzRTY1NrNjVPWVJwemkyUG0tMUNIRnVMOGxLUTJucUprclk', 'large': 'https://an2-img.amz.wtchn.net/image/v2/y2nF6sCn00RvWE1O_4XRuA.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk1qZ3dlRFF3TUhFNE1DSmRMQ0p3SWpvaUwzWXhMMmhxYzNkcGJuWnNlSFJ6YzNVNVlYZGlibkZrSW4wLjE5WEdaMlduZUhTTEJfMGlQazBSMEdZbHB4TzVfaUJ2NWJ0U1U0N1JiUDQ', 'medium': 'https://an2-img.amz.wtchn.net/image/v2/8k6aajhlu9DOW43gStE1NQ.jpg?jwt=ZXlKaGJHY2l
# ...

# %%
new_top_movies = []
for tm in top_movies:
    new_top_movies.extend(tm)

# %%
top_movies = new_top_movies

# %%
cleaned_top_movies = []
for movie in top_movies:
    code = movie['code']
    title = movie['title']
    year = movie['year']
    ratings_avg = movie['ratings_avg']
    nations = [ m['name'] for m in movie['nations']]
    genres = movie['genres']
    movie_dict = {
        "code":code,
        "title": title,
        "year": year,
        "ratings_avg":ratings_avg,
        "nations":nations,
        "genres":genres
    }
    cleaned_top_movies.append(movie_dict)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 3
#       1 cleaned_top_movies = []
#       2 for movie in top_movies:
# ----> 3     code = movie['code']
#       4     title = movie['title']
#       5     year = movie['year']
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# #### 문제3: `cleaned_top_movies`를 데이터 프레임으로 만들고, `watcha_top_movies.csv` 파일로 저장하세요.

# %%
top_movies_df = top_movies_df.drop_duplicates(['code'])
top_movies_df = top_movies_df.reset_index().iloc[:,1:]
top_movies_df.to_csv("watcha_top_movies.csv",index=False)
#top_movies_df = pd.DataFrame(cleaned_top_movies)
# YOUR CODE HERE
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[60], line 1
# ----> 1 top_movies_df = top_movies_df.drop_duplicates(['code'])
#       2 top_movies_df = top_movies_df.reset_index().iloc[:,1:]
#       3 top_movies_df.to_csv("watcha_top_movies.csv",index=False)
#
# NameError: name 'top_movies_df' is not defined

# %% [markdown]
# #### 문제4: `top_movies_df`에서 `code` 칼럼은 영화의 상세 페이지라는 것을 확인했습니다. 이 사실을 이용해서 영화의 줄거리 소개 정보를 포함하는 `plot` 칼럼을 추가로 만들고 크롤링한 줄거리를 여기에 저장하는 코드를 만들어 보세요.

# %%
response = requests.get('https://pedia.watcha.com/api/contents/tRaDAW3', cookies=cookies, headers=headers)

response.json()
# Out:
# {'metadata': {'ad': None,
#   'event_banner': [{'network': 'watcha',
#     'id': 3432,
#     'title': '[광고] <도그맨> 보드 배너',
#     'image_url': 'https://an2-img.amz.wtchn.net/image/v2/os3GYpXUnejnjNoyuKaYxg.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1KbklsMHNJbkFpT2lJdmRqSXZjM1J2Y21VdmNISnZiVzkwYVc5dUx6UXhPRGcyTURnek5qRXhPREl5T0NKOS40Wlo1NFRHdXUzX01oakNDdHZSZEg4cElkM0FIY2lJVExTNEM2OG11T2hN',
#     'sponsored': True,
#     'duration': None,
#     'background_color': '#0f0b0d',
#     'action_url': 'https://www.youtube.com/watch?v=PYS2t_i644c&browser_open_type=external',
#     'type': 'event_banner_image',
#     'small_image_url': 'https://an2-img.amz.wtchn.net/image/v2/irhzZfheWg2KMZzcRyVXUg.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1KbklsMHNJbkFpT2lJdmRqSXZjM1J2Y21VdmNISnZiVzkwYVc5dUx6RTRNREV5T0RFeU1qTTBNVEEzTmlKOS5MWlpyTm44cTJMTmtxRjVXcGoycTkwTWMzTnRSdnNmaGkwV01FUC1DSnA4',
#     'small_image_bg_color': '#0f0b0d'}]},
#  'result': {'code': 'tRaDAW3',
# ...

# %%
# !pip install tqdm
# Out:
# ...
#   Using cached tqdm-4.66.1-py3-none-any.whl.metadata (57 kB)
# Using cached tqdm-4.66.1-py3-none-any.whl (78 kB)
# ...

# %%
from tqdm import tqdm

tqdm.pandas()

# %%
def get_plot(code):
    response = requests.get(f'https://pedia.watcha.com/api/contents/{code}', cookies=cookies, headers=headers)
    description = response.json()['result']['description']
    return description
top_movies_df['plot'] =  top_movies_df['code'].progress_apply(get_plot)
# Out:
# 100%|██████████| 300/300 [02:09<00:00,  2.31it/s]

# %% [markdown]
# ### 과제: Watcha의 평가하기 기능(로그인 필요)은 랜덤으로 영화를 가져와서 목록을 만들어 보여주고 있습니다. 이 사실을 잘 활용해서 가능한한 많은 영화 데이터를 크롤링해 보세요.

# %%
import requests

response = requests.get('https://pedia.watcha.com/api/evaluations/movie', params=params, cookies=cookies, headers=headers)
response.json()
# Out:
# {'metadata': {'list': {'id': 'movie_random',
#    'title': '랜덤 영화',
#    'image': 'https://an2-img.amz.wtchn.net/image/v2/zMYCZnW2aGuEbeqISUgWiw.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk5ESXdlRE13TUhFNE1DSmRMQ0p3SWpvaUwzWXhMMloyZFhSdmVXUjNZbXB4YzNaMVkyaDNaR1EwSW4wLjluc1VrUDJGMGZ2NHdsXzBDd2Q3MXpYSVpsQU9NdTNIZ1lWd184MndlcXc'},
#   'lists_count': 25},
#  'result': {'prev_uri': '/api/evaluations/movie?list_id=movie_random&page=12&size=9',
#   'next_uri': '/api/evaluations/movie?list_id=movie_random&page=14&size=9',
#   'result': [{'code': 'm5NVQ17',
#     'content_type': 'movies',
#     'title': '미성년',
#     'year': 2018,
#     'poster': {'hd': 'https://an2-img.amz.wtchn.net/image/v2/kdw0BLkPYngAUj-5Jq3LZw.jpg?jwt=ZXlKaGJHY2lPaUpJVXpJMU5pSjkuZXlKdmNIUnpJanBiSW1SZk9EazJlREV5T0RCeE9EQWlYU3dpY0NJNklpOTJNUzlzYldWbmVHOXZaR2R5YVdKbWRHMW5aRE40WkNKOS45VVdReWswWTR5WVFacWJROHd1bXBYREM2ckY5XzNqTms2LVlibmF0M1VZ',
# ...
